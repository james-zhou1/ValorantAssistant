# %%
from GEA_database_management import *

# %%
# #I used this code to test if all match IDs are unique or not
# from GEA_transformation_functions import get_all_location_data


# allmatches = get_examined_matches('GEA_data_GEA')
# allmatches = list(allmatches)

# clear_collection('fixed_data_GEA', 'GEA_data_GEA')
# examined = set()
# test_GEA_struct = get_all_location_data("", allmatches, examined_matches=examined)


# store_examined_matches('GEA_data_GEA', examined)
# append_fixed_data_GEA('GEA_data_GEA', test_GEA_struct)

# %%
players_group_1 = [
    {
        'name': 'GEA OldAsian', 
        'tag': 'GEA'
    }
]
players_group_2 = [
    {
        'name': 'GEA OldAsian', #test if duplicates are gone
        'tag': 'GEA'
    },
    {
        'name': 'GEA joli',
        'tag': 'brrr'
    }

]
players_group_all = [
    {
        'name': 'GEA OldAsian', 
        'tag': 'GEA'
    },
    {
        'name': 'GEA joli',
        'tag': 'brrr'
    },
    {
        'name': 'GEA ClickMouse', 
        'tag': '9338'
    },
    {
        'name': 'GEA SpringSwimmer',
        'tag': 'brrr'
    },
    {
        'name': 'GEA stoober',
        'tag': 'TAG'
    }

]

# %%
# Out:
# Collection 'leaderboard_data_GEA' already exists.
# updated examined_matches.

# %%
update_leaderboard_data_db()
# Out:
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
# Making request...
# 			request made.
# 				Alleged requests remaining: [-1]
# 				sleeping for [43 + 2] sec
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [44 + 2] sec
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#    Number of Matches: [844]
# START!
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 1 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 2 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 3 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [44 + 2] sec
#
# Examining Match [ 4 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 5 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 6 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 7 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 8 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 9 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 10 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 11 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 12 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 13 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 14 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 15 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 16 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 17 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 18 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 19 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 20 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 21 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 22 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 23 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 24 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 25 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 26 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 27 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 28 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 29 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 30 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 31 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 32 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 33 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [33 + 2] sec
#
# Examining Match [ 34 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 35 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 36 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 37 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 38 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 39 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 40 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 41 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 42 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 43 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 44 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 45 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 46 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 47 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 48 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 49 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 50 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 51 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 52 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 53 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 54 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 55 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 56 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 57 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 58 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 59 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 60 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 61 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [32 + 2] sec
#
# Examining Match [ 62 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 63 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 64 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 65 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 66 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 67 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 68 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 69 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 70 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 71 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 72 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 73 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 74 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 75 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 76 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 77 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 78 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 79 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 80 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 81 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 82 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 83 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 84 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 85 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 90 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 91 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [-1]
# 				sleeping for [31 + 2] sec
#
# Examining Match [ 92 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 102 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 103 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 104 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 105 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 106 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 107 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 108 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 110 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 111 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 112 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 113 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 114 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 115 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 116 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 118 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 119 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 120 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 121 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 122 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 123 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 124 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 125 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 126 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [29 + 2] sec
#
# Examining Match [ 127 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 128 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 129 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 132 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 133 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 134 ]/ 844
# ----CURRENT MAP: [Split]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 135 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 136 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 137 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 138 ]/ 844
# ----CURRENT MAP: [Breeze]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 139 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 140 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 141 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 142 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 143 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 144 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 145 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 146 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 147 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 148 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 149 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 150 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 151 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [30 + 2] sec
#
# Examining Match [ 152 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 153 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 154 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 155 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 156 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 157 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 158 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 159 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 160 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 161 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 162 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 163 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 164 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 165 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 166 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 167 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 168 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 169 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 170 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 171 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 172 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 173 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 174 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 175 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [30 + 2] sec
#
# Examining Match [ 176 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 177 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 178 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 179 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 180 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 181 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 182 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 183 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 184 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 185 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 186 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 187 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 188 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 189 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 190 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 191 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 192 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 193 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 194 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 195 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 196 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 197 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 198 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 199 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [-1]
# 				sleeping for [29 + 2] sec
#
# Examining Match [ 200 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 201 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 202 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 203 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 204 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 205 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 206 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 207 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 208 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 209 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 210 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 211 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 212 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 213 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 214 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 215 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 216 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 217 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 218 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 219 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 220 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [28 + 2] sec
#
# Examining Match [ 221 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 222 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 223 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 224 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 225 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 226 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 227 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 228 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 229 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 230 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 231 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 232 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 233 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 234 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 235 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 236 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 238 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 239 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 240 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [-1]
# 				sleeping for [25 + 2] sec
#
# Examining Match [ 241 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 242 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 243 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 244 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 245 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 246 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 247 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 248 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 249 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 250 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 251 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 253 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 254 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 255 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 256 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 257 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 258 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 259 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 260 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 261 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 262 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [29 + 2] sec
#
# Examining Match [ 263 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 264 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 265 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 266 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 267 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 268 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 269 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 270 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 271 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 272 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 273 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 274 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 275 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 276 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 277 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 278 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 279 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 280 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 281 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 282 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 283 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 284 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [29 + 2] sec
#
# Examining Match [ 285 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 286 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 287 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 288 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 289 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 290 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 293 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 294 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 295 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 296 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 297 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 298 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 299 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 300 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 302 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 303 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 304 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 305 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 306 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 307 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 308 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 309 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 310 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 311 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 312 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [-1]
# 				sleeping for [30 + 2] sec
#
# Examining Match [ 313 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 314 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 315 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 316 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 317 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 318 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 319 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 320 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 322 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 323 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 324 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 325 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 326 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 327 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 328 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 329 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 330 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 331 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 332 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 333 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 334 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 335 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 336 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [29 + 2] sec
#
# Examining Match [ 337 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 338 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 339 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 340 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 341 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 342 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 343 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 344 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 345 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 346 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 347 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 348 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 349 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 350 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 351 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 352 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 353 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 354 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 355 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 356 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 357 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 358 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 359 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 360 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 361 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 362 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# ...
# 				Alleged requests remaining: [27]
#
# Examining Match [ 724 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 725 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 726 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 727 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 728 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 729 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 730 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 731 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 732 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 733 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 734 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 735 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 736 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 737 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 738 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 739 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 741 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 742 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [-1]
# 				sleeping for [27 + 2] sec
#
# Examining Match [ 743 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 744 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 745 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 747 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 748 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 749 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 750 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 751 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 752 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 753 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 755 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 756 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 757 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 758 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 759 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 760 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 761 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 762 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [27 + 2] sec
#
# Examining Match [ 763 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 764 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 765 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 766 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 767 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 768 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 769 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 770 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 771 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 772 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 773 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 774 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 775 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 776 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 777 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 778 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 779 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 780 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 781 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 782 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [-1]
# 				sleeping for [26 + 2] sec
#
# Examining Match [ 783 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 784 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 785 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 786 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 787 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 788 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 789 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 790 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 791 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 792 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [14]
#
# Examining Match [ 793 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 794 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 795 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 796 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 797 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 798 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 799 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 800 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 801 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [27 + 2] sec
#
# Examining Match [ 802 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [29]
#
# Examining Match [ 803 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 804 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 805 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 806 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 807 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [22]
#
# Examining Match [ 808 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [20]
#
# Examining Match [ 809 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 810 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [18]
#
# Examining Match [ 811 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 812 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [16]
#
# Examining Match [ 813 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 814 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 815 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 816 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [10]
#
# Examining Match [ 817 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [8]
#
# Examining Match [ 818 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [6]
#
# Examining Match [ 819 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 820 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [3]
#
# Examining Match [ 821 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 822 ]/ 844
# ----CURRENT MAP: [Lotus]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [29 + 2] sec
#
# Examining Match [ 823 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [28]
#
# Examining Match [ 824 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [27]
#
# Examining Match [ 825 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [26]
#
# Examining Match [ 826 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [25]
#
# Examining Match [ 827 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [24]
#
# Examining Match [ 829 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [23]
#
# Examining Match [ 830 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [21]
#
# Examining Match [ 831 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [19]
#
# Examining Match [ 832 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [17]
#
# Examining Match [ 833 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [15]
#
# Examining Match [ 834 ]/ 844
# ----CURRENT MAP: [Sunset]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [13]
#
# Examining Match [ 835 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [12]
#
# Examining Match [ 836 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [11]
#
# Examining Match [ 837 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [9]
#
# Examining Match [ 838 ]/ 844
# ----CURRENT MAP: [Bind]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [7]
#
# Examining Match [ 839 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [5]
#
# Examining Match [ 840 ]/ 844
# ----CURRENT MAP: [Haven]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [4]
#
# Examining Match [ 841 ]/ 844
# ----CURRENT MAP: [Icebox]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [2]
#
# Examining Match [ 842 ]/ 844
# ----CURRENT MAP: [Abyss]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [1]
#
# Examining Match [ 843 ]/ 844
# ----CURRENT MAP: [Ascent]----
# Making request...
# 			request made.
# 				Alleged requests remaining: [0]
# 				sleeping for [28 + 2] sec
#
# Examining Match [ 844 ]/ 844
# ----CURRENT MAP: [Lotus]----
# updated examined_matches.
# uploading data for Abyss
# done
# adding to num matches
# uploading data for Sunset
# done
# adding to num matches
# uploading data for Bind
# done
# adding to num matches
# uploading data for Icebox
# done
# adding to num matches
# uploading data for Ascent
# done
# adding to num matches
# uploading data for Haven
# done
# adding to num matches
# uploading data for Lotus
# done
# adding to num matches
# uploading data for Split
# done
# adding to num matches
# uploading data for Breeze
# done
# adding to num matches
# append_fixed_data_GEA is done
